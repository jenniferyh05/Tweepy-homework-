# %%
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')

avg=[-0.029499999999999988, 0.015449999999999998, -0.05616000000000001, 0.16905699999999999, 0.06007100000000001]
users=["BBC","NYT","CNN","CBS","Fox"]
plt.bar(users,avg,color=["red",'blue','yellow','green','coral'])
plt.title("Media Sentiment Analysis")
plt.xlabel("Media")
plt.ylabel("Overall Sentiment")
# Out:
# Text(0,0.5,'Overall Sentiment')
